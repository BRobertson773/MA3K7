# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from sympy.abc import m,n,p

# %%
M = sp.solve(m**2-0.5*m-0.5,m)
print(M)
x, y = sp.symbols("x,y")
A = sp.Matrix([[1, 1], [M[0], M[1]]])
b = sp.Matrix([0, 1])
C, = sp.linsolve((A, b), x, y)
print(C)
# Out:
# [-0.500000000000000, 1.00000000000000]
# (-0.666666666666667, 0.666666666666667)

# %%
x = np.arange(0,26)

y = (2/3) + (-2/3) * ((-1/2)**x)

plt.plot(x,y,'kx')
plt.show()

# %%
x = sp.Function('x')


def solver(equation,order):
    
    
    init = [0]
    
    for i in range(0,order-1):
        init.append(2**-i)
    
    
    return sp.rsolve(equation,x(n),init)

for j in range(2,10):
    from sympy.abc import n
    y = solver(x(n+j)-0.5*x(n+j-1)-0.5*x(n),j)
    n = np.arange(0,101)
    y = str(y)
    I = (-1)**1/2
    plt.plot(n,eval(y),'kx')
    print(y)
    plt.show()
# Out:
# 0.666666666666667 - 0.666666666666667*(-0.5)**n
# (-0.25 - 0.661437827766148*I)**n*(-0.25 + 0.28347335475692*I) + (-0.25 + 0.661437827766148*I)**n*(-0.25 - 0.28347335475692*I) + 0.5
# -0.224419816569977*(-0.738983621504506)**n + (-0.0877900917150115 + 0.27962552111218*I)*(0.119491810752253 - 0.813834558901752*I)**n + (-0.0877900917150115 - 0.27962552111218*I)*(0.119491810752253 + 0.813834558901752*I)**n + 0.4
# (-0.621034838410277 - 0.502296514296184*I)**n*(-0.157711438706491 + 0.0775858990769075*I) + (-0.621034838410277 + 0.502296514296184*I)**n*(-0.157711438706491 - 0.0775858990769075*I) + (-0.00895522796017604 + 0.248504084456552*I)*(0.371034838410277 - 0.803771941261526*I)**n + (-0.00895522796017604 - 0.248504084456552*I)*(0.371034838410277 + 0.803771941261526*I)**n + 0.333333333333333
# ...

# %%
x = sp.Function('x')


def solver(equation,order):
    
    
    init = [0]
    
    for i in range(0,order-1):
        init.append(2**-i)
    
    
    return sp.rsolve(equation,x(n),init)

for j in range(2,10):
    from sympy.abc import n
    y = solver(x(n+j)-0.5*x(n+j-1)-0.5*x(n),j)
    n = np.arange(0,101)
    y = str(y)
    I = (-1)**(1/2)
    plt.plot(n,eval(y),'kx')
    print(y)
    plt.show()
# Out:
# 0.666666666666667 - 0.666666666666667*(-0.5)**n
# (-0.25 - 0.661437827766148*I)**n*(-0.25 + 0.28347335475692*I) + (-0.25 + 0.661437827766148*I)**n*(-0.25 - 0.28347335475692*I) + 0.5
# -0.224419816569977*(-0.738983621504506)**n + (-0.0877900917150115 + 0.27962552111218*I)*(0.119491810752253 - 0.813834558901752*I)**n + (-0.0877900917150115 - 0.27962552111218*I)*(0.119491810752253 + 0.813834558901752*I)**n + 0.4
# (-0.621034838410277 - 0.502296514296184*I)**n*(-0.157711438706491 + 0.0775858990769075*I) + (-0.621034838410277 + 0.502296514296184*I)**n*(-0.157711438706491 - 0.0775858990769075*I) + (-0.00895522796017604 + 0.248504084456552*I)*(0.371034838410277 - 0.803771941261526*I)**n + (-0.00895522796017604 - 0.248504084456552*I)*(0.371034838410277 + 0.803771941261526*I)**n + 0.333333333333333
# ...
